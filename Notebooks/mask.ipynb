# %%
import healpy as hp
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import cmb

# %%
sys.path.append('../')

# %%
# %load_ext autoreload
# %autoreload 2
from lbxs4.config import MASKDIR,DATDIR
from lbxs4.filtering import Filtering
from lbxs4.simulations import LBSky

# %%
dire = '/pscratch/sd/l/lonappan/LBxS4'

# %%
maskpath = os.path.join(MASKDIR, 'LB_Nside2048_fsky_0p8_binary.fits')

# %%
sky = LBSky(dire,512)

# %%
f = Filtering(dire,sky,maskpath)

# %%
f.plot_cinv(0)
# Out:
# ../lbxs4/filtering.py:126: RuntimeWarning: divide by zero encountered in true_divide

# %%
f.plot_wE(0)

# %%
clen = os.path.join(DATDIR,'FFP10_wdipole_lensedCls.dat')

# %%
new = cmb.read_camb_cls(clen,ftype='lens',output='array')

# %%
hp.mollview(hp.read_map(os.path.join(MASKDIR, 'LB_Nside2048_fsky_0p8_binary.fits')))

# %%
old = cmb.read_camb_cls('/global/cfs/cdirs/litebird/simulations/maps/lensing_project_paper/S4BIRD/CAMB/BBSims_lensed_dls.dat',ftype='lens',output='array')

# %%
plt.loglog(new[2])
plt.loglog(old[2])

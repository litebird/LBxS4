# %%
import sys
sys.path.append('../')
import healpy as hp
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2
from lbxs4 import CMBLensed
from lbxs4.simulations import LBSky
from lbxs4.instrument import LiteBIRD

# %%
c = CMBLensed(nside=512)

# %%
tqu = c.TQU(0)

# %%
hp.mollview(tqu[1], title='T')

# %%
LiteBIRD().get_fwhm('L1-078')
# Out:
# 43.8

# %%
LiteBIRD().tag
# Out:
# array(['H3-402', 'H2-337', 'H1-280', 'H2-235', 'H1-195', 'M1-195',
#        'M2-166', 'M1-140', 'M2-119', 'M1-100', 'L4-140', 'L3-119',
#        'L4-100', 'L2-089', 'L3-089', 'L1-078', 'L4-078', 'L2-068',
#        'L3-068', 'L1-060', 'L2-050', 'L1-040'], dtype='<U6')

# %%
LiteBIRD().get_fwhm('L1-078')
# Out:
# 43.8

# %%
LiteBIRD().get_fwhm('L4-078')
# Out:
# 36.9

# %%
LiteBIRD().get_frequency('L1-078')
# Out:
# 78.0

# %%
LiteBIRD().get_frequency('L4-078')
# Out:
# 78.0

# %%
from lbxs4.noise import NoiseModel

# %%
N = NoiseModel()

# %%
N.noise_freq('L4-078',0)
# Out:
# array([[ 4.91856020e-07,  6.36431630e-07,  2.58039286e-06, ...,
#         -1.56774918e-07, -8.26520605e-07,  7.03035877e-07],
#        [-2.61457702e-06,  2.03543733e-06, -5.12035366e-07, ...,
#          1.10857393e-07,  4.57757944e-07,  4.61831994e-07],
#        [ 6.57741901e-07,  3.11816347e-07,  3.40324833e-07, ...,
#         -6.59235634e-08, -6.67982191e-06, -7.26891066e-07]])

# %%
from lbxs4.foreground import Foregrounds

# %%
dir_downgrade =  '/pscratch/sd/l/lonappan/LBxS4'
fg = Foregrounds(dir_downgrade,512)

# %%
fg.TQU('H3-402')
# Out:
# array([[1839.72422375, 1892.48041783, 1847.34153434, ..., 1881.73045634,
#         1845.87218153, 1861.04532109],
#        [  14.95493654,   -9.54366052,    7.00180954, ...,   22.28947527,
#          -18.69323273,   18.99533072],
#        [  -4.5996605 ,    4.69444631,   -2.94597724, ...,  -20.96580215,
#           22.71424271,  -23.27352211]])

# %%
dire = '/pscratch/sd/l/lonappan/LBxS4'

# %%
lb = LBSky(dire,512)

# %%
alms = lb.HILC(0)

# %%
ncl = lb.HILC_ncl(0)

# %%
ncl[0]
# Out:
# array([4.99896387e-09, 3.49796379e-09, 2.67745294e-09, ...,
#        2.16129101e-06, 2.32864547e-06, 2.50703497e-06])

# %%
plt.loglog(hp.alm2cl(alms[0]),label='TT')
plt.loglog(ncl[0])
plt.loglog(hp.alm2cl(alms[1]),label='EE')
plt.loglog(ncl[1])
plt.loglog(hp.alm2cl(alms[2]),label='BB')
plt.loglog(ncl[2])

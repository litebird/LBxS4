# %%
import sys
sys.path.append('../')
import numpy as np
import os

# %%
# %load_ext autoreload
# %autoreload 2
from lbxs4.multitracer import mass_tracer
from lbxs4.config import SPECTRADIR
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
m = mass_tracer(50, 600)

# %%
m.cov_signal()
# Out:
# array([[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          2.37550849e-08, 2.36958815e-08, 2.36369096e-08],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          2.37550849e-08, 2.36958815e-08, 2.36369096e-08],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          4.77898963e-12, 4.76639376e-12, 4.75383891e-12],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          3.40551535e-08, 3.39666472e-08, 3.38784861e-08],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          3.40084225e-08, 3.39020202e-08, 3.37964328e-08],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          3.36810458e-08, 3.36045216e-08, 3.35276429e-08]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          2.37550849e-08, 2.36958815e-08, 2.36369096e-08],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
# ...

# %%
np.loadtxt(os.path.join(SPECTRADIR,'clklbklb.dat'),unpack=True)[:,1]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 8.04936811e-08, ...,
#        3.35200228e-09, 3.34932268e-09, 3.34664659e-09])

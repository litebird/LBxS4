# %%
import healpy as hp
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
sys.path.append('../')

# %%
# %load_ext autoreload
# %autoreload 2
from lbxs4.simulations import LBSky
from lbxs4.simulations import S4Sky
import lbxs4.utils as utils
from lbxs4.config import DATDIR
from lbxs4.filtering import FiltCoadd

# %%
dire = '/pscratch/sd/l/lonappan/LBxS4v1'

# %%
lblib = LBSky(512)
s4lib = S4Sky(1024)

# %%
fc_lb = FiltCoadd(dire,lblib=lblib)
# Out:
# INFO:LiteBIRD simulation library is loaded

# %%
fc_lb.plot_W_E(0)

# %%
fc_lb.plot_W_B(0)
# Out:
#  B
#            1
#            2           1
#   1.014872572899452E-006  0.799068211311351
#   7.486001786408860E-008  0.799068211311351
